# %% [markdown]
# ![kdata](../img/kdata-logo.png)
#
# # Naming Convention
#
# Date : 19.07.12
#
# ## Naming Styles
# 1. b: 한 개 소문자
# 2. B: 한 개 대문자
# 3. lowercase
# 4. lowercase_with_underscores
# 5. UPPERCASE
# 6. UPPERCASE_WITH_UNDERSCORES
# 7. CapWords CamelCase (CapitalizedWords) # Class
# 8. mixedCase # Python에서는 쓰지말자
# 9. Capitalized_Words_With_Underscores # 이렇게 쓰지 말자
#
# ## 도전하세요!
# ![image.png](attachment:image.png)

# %%
class Dog:
    def __init__(self, name = ""): # 생성자는 self 키워드 필수
        self.name = name
        self.has_house = False
        
    def go_to(self):
        pass

# %%
d = Dog("my-puppy")

# %%
d.go_to()

# %% [markdown]
# ### Standard Library 1 : Module, Class, Method
# - 메소드 : 동사 시작, `-`로 구성
# - 에트리뷰트 : 소문자로
#
# ### Standard Library 2 : Legacy naming styles
# ```
# import os
#
# statinfo = os.stat("my_module.py")
# print("st_size=", statinfo.st_size)
# print("st_ino=", statinfo.st_ino)
# print("st_uid=", statinfo.st_uid)
# ```
#
# ### Standard Library 3 : Exception Rule
# ```
# >>> 10 * (1/0)
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# ZeroDivisionError: division by zero
#
# >>> 4 + spam*3
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# NameError: …
#
# >>> '2' + 2
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# TypeError: …
# ```

# %% [markdown]
# ## Underscore rules
#
# ### var_name_ : Single Trailing Underscore

# %%
def def_():  # 이미 사용하고 있는 단어일 경우
    return "Hello world!"


print(def_())
def__ = 5
# Out:
# Hello world!

# %% [markdown]
# ## _var_name : Single Leading Underscore

# %%
_THIS_IS_PRIVATE_E = 2.71828


def _get_evalue():
    return _THIS_IS_PRIVATE_E


class _E_class:
    def __init__(this):
        this._my_value = 50

    def _get_value(this): # py파일에서만 쓸거니 쓰지 마세요라는 뜻ㅁ
        return this._my_value


print(_THIS_IS_PRIVATE_E)
print(_get_evalue())
print(_E_class()._my_value)
print(_E_class()._get_value())
# Out:
# 2.71828
# 2.71828
# 50
# 50

# %% [markdown]
# ## `__`var_name 1 : Double Leading Underscore

# %%
__THIS_IS_PRIVATE_E = 2.71828


def __get_evalue(): # 앞에 __ 붙은건 클래스 안에서만 쓰자
    return __THIS_IS_PRIVATE_E


class __E_class:
    def __init__(this):
        this.__my_value = 50

    def __get_value(this):
        return this.__my_value


print(__THIS_IS_PRIVATE_E)
print(__get_evalue())
print(dir(_E_class))
print(__E_class()._E_class__my_value)
print(__E_class()._E_class__get_value())
# Out:
# 2.71828
# 2.71828
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_value']
# 50
# 50

# %% [markdown]
# ## `__`var_name`__`: Double Leading and Trailing Underscore

# %% [markdown]
# ## 도전하세요

# %%
def get_my_unit():
    return "cm"

class Math:
    __PI = 3.141592
    
    def __init__(self):
        pass
    
    def info(self):
        return "It's Me"
    
    def _get_value(self): # protected니까 맨앞에 underscore 쓴다
        return 5

# %%
m = Math()
print(m.info())
MY_DOG = "get my dog"
# Out:
# It's Me
