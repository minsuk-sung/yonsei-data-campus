# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# ## 6. 계층 색인 (다중 색인)
# ### 2개 이상의 색인(인덱스)를 지정할 수 있다.
# ### 차원이 높은 (고차원) 데이터를 낮은 차원의 형식으로 다룰 수 있게 해주는 기능

# %%
# 샘플 데이터 생성
np.random.seed(0)
df = pd.DataFrame(np.random.randint(50, 100, (5, 4)), 
                  columns=[[2016, 2016, 2017, 2017], ['영어','수학','영어','수학']], 
                  index = ['Kim','Park','Lee','Jung','Moon'])

# %%
df
# Out:
#      2016     2017
#        영어  수학   영어  수학
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56
# Jung   74  74   62  51
# Moon   88  89   73  96

# %%
df.index
# Out:
# Index(['Kim', 'Park', 'Lee', 'Jung', 'Moon'], dtype='object')

# %%
df.columns
# Out:
# MultiIndex(levels=[[2016, 2017], ['수학', '영어']],
#            codes=[[0, 0, 1, 1], [1, 0, 1, 0]])

# %% [markdown]
# ## 6-1. 인덱싱

# %%
#2016년 영어, 수학 성적 조회
df[2016]
# Out:
#       영어  수학
# Kim   94  97
# Park  53  89
# Lee   71  86
# Jung  74  74
# Moon  88  89

# %%
#2016년 영어 성적만 조회
#최상위 인덱스부터 명시하며, 인덱싱하고자하는 색인들을 튜플 형태로 정의
df[(2016,"영어")]
# Out:
# Kim     94
# Park    53
# Lee     71
# Jung    74
# Moon    88
# Name: (2016, 영어), dtype: int64

# %%
df[2016]["영어"] # 위와 같은 방식임
# Out:
# Kim     94
# Park    53
# Lee     71
# Jung    74
# Moon    88
# Name: 영어, dtype: int64

# %%
# Kim의 성적만 선택
#특정 row를 선택
df.loc['Kim']
# Out:
# 2016  영어    94
#       수학    97
# 2017  영어    50
#       수학    53
# Name: Kim, dtype: int64

# %%
# 실습. Kim, Park, Lee의 성적만 선택
df.loc[['Kim','Park','Lee']]
# Out:
#      2016     2017
#        영어  수학   영어  수학
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56

# %%
df['Kim':'Lee']
# Out:
#      2016     2017
#        영어  수학   영어  수학
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56

# %%
# 최상위 색인이 아닌 색인으로만 인덱싱하고 싶은 경우에는 xs() 함수를 사용.
# 2016, 2017년도 영어 성적만 선택
df[[(2016,"영어"),(2017,"영어")]]
# Out:
#      2016 2017
#        영어   영어
# Kim    94   50
# Park   53   59
# Lee    71   73
# Jung   74   62
# Moon   88   73

# %%
# 최상위가 아니기 때문에 별도의 함수를 적용
df.xs('영어',axis=1,level=1) # level은 0부터 최상위임
# Out:
#       2016  2017
# Kim     94    50
# Park    53    59
# Lee     71    73
# Jung    74    62
# Moon    88    73

# %% [markdown]
# ## 6-2. 메타데이터 설정 (set_names)

# %%
# 인덱스에 이름 부여하기 (set_names)
# 로우 인덱스의 이름을 '학생명'이라고 정의하기
df.index.set_names('학생명',inplace=True)
df
# Out:
#      2016     2017
#        영어  수학   영어  수학
# 학생명
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56
# Jung   74  74   62  51
# Moon   88  89   73  96

# %%
# 실습. 컬럼들의 이름을 각각 년도와 과목으로 정의하기
df.columns.set_names(['연도','과목'],inplace=True)
df
# Out:
# 연도   2016     2017
# 과목     영어  수학   영어  수학
# 학생명
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56
# Jung   74  74   62  51
# Moon   88  89   73  96

# %% [markdown]
# ## 6-3. 몇 가지 주요 함수들
# ### 1) swaplevel(index1, index2, axis)
# **index1과 index2의 위치를 변경**함.
# **index1과 index2가 로우 인덱스인 경우, axis = 0, 컬럼인덱스면 1 (기본값은 0)**

# %%
df
# Out:
# 연도   2016     2017
# 과목     영어  수학   영어  수학
# 학생명
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56
# Jung   74  74   62  51
# Moon   88  89   73  96

# %%
df.swaplevel('연도','과목',axis=1)
# Out:
# 과목     영어   수학   영어   수학
# 연도   2016 2016 2017 2017
# 학생명
# Kim    94   97   50   53
# Park   53   89   59   69
# Lee    71   86   73   56
# Jung   74   74   62   51
# Moon   88   89   73   96

# %%
df.swaplevel(0,1,axis=1) # 0이 최상위 레벨, 가독성이 떨어지므로 좋은 코드는 아니라고 할 수 있음
# Out:
# 과목     영어   수학   영어   수학
# 연도   2016 2016 2017 2017
# 학생명
# Kim    94   97   50   53
# Park   53   89   59   69
# Lee    71   86   73   56
# Jung   74   74   62   51
# Moon   88   89   73   96

# %%
# 년도와 과목의 위치를 변경
df.swaplevel('연도','과목',axis=1).sort_index(axis=1)
# Out:
# 과목     수학        영어
# 연도   2016 2017 2016 2017
# 학생명
# Kim    97   53   94   50
# Park   89   69   53   59
# Lee    86   56   71   73
# Jung   74   51   74   62
# Moon   89   96   88   73

# %% [markdown]
# ## 2) stack(), unstack() 함수
# ### stack(level) : 컬럼 인덱스를 로우 인덱스로 옮길 때 사용.
# ### unstack(level): 로우 인덱스를 컬럼 인덱스로 옮길 때 사용.
# ### level 인자는 옮기고자 하는 인덱스의 위치를 표기함. 명시하지 않은 경우, 최하단의 인덱스를 이동시킴.
# ### level은 최상위가 0이고, 1씩 증가함

# %%
df
# Out:
# 연도   2016     2017
# 과목     영어  수학   영어  수학
# 학생명
# Kim    94  97   50  53
# Park   53  89   59  69
# Lee    71  86   73  56
# Jung   74  74   62  51
# Moon   88  89   73  96

# %%
# 컬럼 인덱스 과목을 로우 인덱스로 변경하고 df2에 저장
# df.stack(0)
df.stack('연도')
# Out:
# 과목         수학  영어
# 학생명  연도
# Kim  2016  97  94
#      2017  53  50
# Park 2016  89  53
#      2017  69  59
# Lee  2016  86  71
#      2017  56  73
# Jung 2016  74  74
#      2017  51  62
# Moon 2016  89  88
#      2017  96  73

# %%
# df.stack(1)
df2 = df.stack('과목')
df2
# Out:
# 연도       2016  2017
# 학생명  과목
# Kim  수학    97    53
#      영어    94    50
# Park 수학    89    69
#      영어    53    59
# Lee  수학    86    56
#      영어    71    73
# Jung 수학    74    51
#      영어    74    62
# Moon 수학    89    96
#      영어    88    73

# %% [markdown]
# ### df2를 대상으로 아래 실습 문제 수행

# %%
# 실습. Kim의 성적만 선택
df2.loc['Kim']
# Out:
# 연도  2016  2017
# 과목
# 수학    97    53
# 영어    94    50

# %%
# 실습. Park의 수학 성적만 선택
df2.loc[('Park','수학')]
# Out:
# 연도
# 2016    89
# 2017    69
# Name: (Park, 수학), dtype: int64

# %%
# 실습. 모든 학생들의 영어 성적만 선택 
# df2.loc[[('Kim','영어'),('Park','영어'),('Lee','영어'),('Jung','영어'),('Moon','영어')]]
df2.xs('영어',axis=0,level=1)
# Out:
# 연도    2016  2017
# 학생명
# Kim     94    50
# Park    53    59
# Lee     71    73
# Jung    74    62
# Moon    88    73

# %%
# 실습. Park 학생의 2016년 영어 성적만 출력
df2.loc[('Park','영어')][2016]
# Out:
# 53

# %%
# 실습. 학생들의 과목별 성적의 평균을 구해서, 새로운 컬럼 '평균'으로 저장
df2['평균'] = (df2[2016] + df2[2017]) / 2
df2
# Out:
# 연도       2016  2017    평균
# 학생명  과목
# Kim  수학    97    53  75.0
#      영어    94    50  72.0
# Park 수학    89    69  79.0
#      영어    53    59  56.0
# Lee  수학    86    56  71.0
#      영어    71    73  72.0
# Jung 수학    74    51  62.5
#      영어    74    62  68.0
# Moon 수학    89    96  92.5
#      영어    88    73  80.5

# %%
df2.columns
# Out:
# Int64Index([2016, 2017], dtype='int64', name='연도')

# %%
df2['평균2'] = df2.mean(axis=1)
df2
# Out:
# 연도       2016  2017    평균   평균2
# 학생명  과목
# Kim  수학    97    53  75.0  75.0
#      영어    94    50  72.0  72.0
# Park 수학    89    69  79.0  79.0
#      영어    53    59  56.0  56.0
# Lee  수학    86    56  71.0  71.0
#      영어    71    73  72.0  72.0
# Jung 수학    74    51  62.5  62.5
#      영어    74    62  68.0  68.0
# Moon 수학    89    96  92.5  92.5
#      영어    88    73  80.5  80.5

# %% [markdown]
# # 실습
# ## data/NC Dinos.xlsx 파일을 읽어서, 아래 결과처럼 나오도록 하시오.
# <img src="img/6강/NC계층색인예제.jpg" alt="NC계층색인예제" style="width: 350px;"/>

# %%
data = pd.read_excel('data/NC Dinos.xlsx',sheet_name=None)
nc13,nc14,nc15 = data.values()

# %%
nc13['연도'] = 2013
nc14['연도'] = 2014
nc15['연도'] = 2015

# %%
nc13 = nc13[['선수명','안타','홈런','연도']]
nc14 = nc14[['선수명','안타','홈런','연도']]
nc15 = nc15[['선수명','안타','홈런','연도']]

# %%
ncall = pd.concat([nc13,nc14,nc15],axis=0)

# %%
ncall.set_index(['선수명','연도'],inplace=True)

# %%
ncall = ncall.unstack('연도') #.fillna('-')

# %%
ncall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 강구성 to 허준
# Data columns (total 6 columns):
# (안타, 2013)    20 non-null float64
# (안타, 2014)    20 non-null float64
# (안타, 2015)    20 non-null float64
# (홈런, 2013)    20 non-null float64
# (홈런, 2014)    20 non-null float64
# (홈런, 2015)    20 non-null float64
# dtypes: float64(6)
# memory usage: 1.9+ KB

# %%
ncall[('안타','평균')] = ncall['안타'].mean(axis=1)
ncall[('홈런','평균')] = ncall['홈런'].mean(axis=1)

# %%
ncall = ncall.sort_index(axis=1)
ncall.fillna('-')
# Out:
#        안타                         홈런
# 연도   2013 2014 2015          평균 2013 2014 2015         평균
# 선수명
# 강구성     0    -    1    0.500000    0    -    0   0.000000
# 강민국     -    0    0    0.000000    -    0    0   0.000000
# 강진성     1    -    -    1.000000    0    -    -   0.000000
# 권희동     -   63    -   63.000000    -    7    -   7.000000
# 김동건     2    -    -    2.000000    1    -    -   1.000000
# 김성욱     1    4    -    2.500000    0    1    -   0.500000
# 김종찬     1    -    -    1.000000    0    -    -   0.000000
# 김종호   129    -  125  127.000000    0    -    4   2.000000
# 김준완     -    2   10    6.000000    -    0    0   0.000000
# 김태군     -    -  107  107.000000    -    -    6   6.000000
# 김태우     -    1    -    1.000000    -    0    -   0.000000
# 김태진     -    -    0    0.000000    -    -    0   0.000000
# 나성범    98  157  184  146.333333   14   30   28  24.000000
# 노진혁     -    3    -    3.000000    -    1    -   1.000000
# 마낙길     9    0    -    4.500000    0    0    -   0.000000
# 모창민   109  110   62   93.666667   12   16    6  11.333333
# 박명환*    -    0    -    0.000000    -    0    -   0.000000
# 박민우    11  124  158   97.666667    0    1    3   1.333333
# 박정준    41    -    8   24.500000    4    -    0   2.000000
# 손시헌     -   90  108   99.000000    -    5   13   9.000000
# 용덕한     -    -   12   12.000000    -    -    0   0.000000
# 이상호    31    -    -   31.000000    0    -    -   0.000000
# 이승호     0    -    -    0.000000    0    -    -   0.000000
# 이종욱     -  126  118  122.000000    -    6    5   5.500000
# 이창섭     0    -    0    0.000000    0    -    0   0.000000
# 이현곤    38    -    -   38.000000    0    -    -   0.000000
# 이호준   123  115  132  123.333333   20   23   24  22.333333
# 조영훈   107   29   35   57.000000    6    6    8   6.666667
# 조평호    21    0    8    9.666667    2    0    1   1.000000
# 지석훈    68   58  111   79.000000    3    6   11   6.666667
# 차화준    24    -    -   24.000000    1    -    -   1.000000
# 최재원     -    0   21   10.500000    -    0    2   1.000000
# 테임즈     -  152  180  166.000000    -   37   47  42.000000
# 허준      -    5    -    5.000000    -    0    -   0.000000
